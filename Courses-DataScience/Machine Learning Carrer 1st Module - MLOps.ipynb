# %% [markdown]
# # MLOps Life Cylce
#   - Desing
#   - Development
#   - Deployment

# %% [markdown]
# ## Desing
#   - Context Problem
#   - Added Value
#   - Bussnies Requirement
#   - Key metrics
#   - Data processing
#
# ## Development
#   - Develop machine learning model
#   - Algorithms
#   - Train more than one model to find the most suitable one
#
# ## Deployment
#   - Intregate MLmodel in bussines
#   - Monitoring the performance

# %% [markdown]
# # Roles in MLOps
#  - Bussines Roles
#  - Technical Roles

# %% [markdown]
# ## Bussiness Roles
#   - Budget decisions
#   - Vision of company
#   - Subject Matter Expert
#
#
# ## Technical Roles
#  - Data engineer
#  - Data scientist
#  - Software engineer
#  - ML engineer
#  - Backend engineer

# %% [markdown]
# #MLOps Desing and Development

# %% [markdown]
# ## Data Quality
# - Accuracy
# - Completeness
# - Consistency
# - Timeliness

# %% [markdown]
# ### Data Examples
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Data Ingestion
# 1. Extract from the source (weather)
#
# 2. Transform into the desire format
#
# 3. Load into the DB for storage and recovery

# %% [markdown]
# ## Development
#
# # Featured engineering
#  - Create more features with the same data to add more possibilities
#  - More feature can produce a more accurate model or more stability
#  - Over engineering can lead to noise
#  - More features equal to more computacional cost

# %% [markdown]
# # Monitoring

# %% [markdown]
# ## Statistical Monitoring
#
#
# Focuses on the input and the output data, incluiding predictions
# Just the data
#
# ---
# ## Computational Monitoring
#
# Focuses on technical metrics of the model
# CPU usage, performance, network usage

# %% [markdown]
# ## Feedback Loop
# It's uesed to iimproved the machine learing model

# %% [markdown]
# # MLOps tools

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
